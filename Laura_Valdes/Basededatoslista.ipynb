# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/content/drive/MyDrive/base_limpia (1).csv")

# %%
data.head()
# Out:
#                                      Indicador  \
# 0  Unintended pregnancy rate (model-estimated)
# 1  Unintended pregnancy rate (model-estimated)
# 2  Unintended pregnancy rate (model-estimated)
# 3  Unintended pregnancy rate (model-estimated)
# 4  Unintended pregnancy rate (model-estimated)
#
#                                Pais  Valor_Estimado  Limite_Inferior  \
# 0  Bolivia (Plurinational State of)          104.70               73
# 1      Netherlands (Kingdom of the)           17.53               14
# 2                             Spain           20.26               17
# 3                       Switzerland           20.31               17
# 4                          Portugal           20.90               18
#
#    Limite_Superior
# 0              158
# 1               24
# 2               26
# 3               27
# 4               25

# %%
data= data.drop(["Indicador"],axis=1)

# %%
data.head()
# Out:
#                                Pais  Valor_Estimado  Limite_Inferior  \
# 0  Bolivia (Plurinational State of)          104.70               73
# 1      Netherlands (Kingdom of the)           17.53               14
# 2                             Spain           20.26               17
# 3                       Switzerland           20.31               17
# 4                          Portugal           20.90               18
#
#    Limite_Superior
# 0              158
# 1               24
# 2               26
# 3               27
# 4               25

# %%
data.to_csv("Basededatoslista.csv",index=False)

# %% [markdown]
# # Decisiones
# -
